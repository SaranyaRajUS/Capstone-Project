# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
dataset = pd.read_csv("student_igcse_dataset.csv")
dataset
# Out:
#     student_id entry_grade  age_at_entry  gender parent_education  \
# 0        S1000         3rd           3.3    Male         Master's
# 1        S1001         UKG           7.8  Female       Bachelor's
# 2        S1002         UKG           4.8    Male         Master's
# 3        S1003         2nd           3.2  Female         Master's
# 4        S1004         UKG           7.0  Female      High School
# ..         ...         ...           ...     ...              ...
# 495      S1495         9th           4.5    Male      High School
# 496      S1496         UKG           4.5    Male         Master's
# 497      S1497         6th           4.2  Female       Bachelor's
# 498      S1498         9th           3.9  Female              PhD
# 499      S1499         6th           5.6    Male      High School
#
#     family_income_bracket language_proficiency  attention_span_score  \
# 0                  Middle               Medium                     2
# ...

# %%
null_counts = dataset.isnull().sum()
dataset
# Out:
#     student_id entry_grade  age_at_entry  gender parent_education  \
# 0        S1000         3rd           3.3    Male         Master's
# 1        S1001         UKG           7.8  Female       Bachelor's
# 2        S1002         UKG           4.8    Male         Master's
# 3        S1003         2nd           3.2  Female         Master's
# 4        S1004         UKG           7.0  Female      High School
# ..         ...         ...           ...     ...              ...
# 495      S1495         9th           4.5    Male      High School
# 496      S1496         UKG           4.5    Male         Master's
# 497      S1497         6th           4.2  Female       Bachelor's
# 498      S1498         9th           3.9  Female              PhD
# 499      S1499         6th           5.6    Male      High School
#
#     family_income_bracket language_proficiency  attention_span_score  \
# 0                  Middle               Medium                     2
# ...

# %%
na_counts = dataset.isna().sum()
dataset
# Out:
#     student_id entry_grade  age_at_entry  gender parent_education  \
# 0        S1000         3rd           3.3    Male         Master's
# 1        S1001         UKG           7.8  Female       Bachelor's
# 2        S1002         UKG           4.8    Male         Master's
# 3        S1003         2nd           3.2  Female         Master's
# 4        S1004         UKG           7.0  Female      High School
# ..         ...         ...           ...     ...              ...
# 495      S1495         9th           4.5    Male      High School
# 496      S1496         UKG           4.5    Male         Master's
# 497      S1497         6th           4.2  Female       Bachelor's
# 498      S1498         9th           3.9  Female              PhD
# 499      S1499         6th           5.6    Male      High School
#
#     family_income_bracket language_proficiency  attention_span_score  \
# 0                  Middle               Medium                     2
# ...

# %%
def quanqual(dataset):
    quan = []
    qual = []
    for columnName in dataset.columns:
        if dataset[columnName].dtype == 'O':
            qual.append(columnName)
        else:
            quan.append(columnName)
    return quan, qual

# %%
quan,qual=quanqual(dataset)

# %%
dataset[quan]
# Out:
#      age_at_entry  attention_span_score  social_skills_score  \
# 0             3.3                     2                    4
# 1             7.8                     4                    4
# 2             4.8                     1                    2
# 3             3.2                     4                    2
# 4             7.0                     4                    3
# ..            ...                   ...                  ...
# 495           4.5                     3                    5
# 496           4.5                     3                    5
# 497           4.2                     5                    3
# 498           3.9                     3                    1
# 499           5.6                     1                    4
#
#      cognitive_test_score  has_learning_difficulty  \
# 0                      85                        0
# 1                     110                        0
# 2                     123                        0
# ...

# %%
dataset[qual]
# Out:
#     student_id entry_grade  gender parent_education family_income_bracket  \
# 0        S1000         3rd    Male         Master's                Middle
# 1        S1001         UKG  Female       Bachelor's                Middle
# 2        S1002         UKG    Male         Master's                Middle
# 3        S1003         2nd  Female         Master's                Middle
# 4        S1004         UKG  Female      High School                Middle
# ..         ...         ...     ...              ...                   ...
# 495      S1495         9th    Male      High School                  High
# 496      S1496         UKG    Male         Master's                Middle
# 497      S1497         6th  Female       Bachelor's                   Low
# 498      S1498         9th  Female              PhD                Middle
# 499      S1499         6th    Male      High School                Middle
#
#     language_proficiency
# 0                 Medium
# 1                    Low
# ...

# %%
imp_num = SimpleImputer(missing_values=np.nan, strategy='mean')
dataset[quan] = imp_num.fit_transform(dataset[quan])
dataset[quan]
# Out:
#      age_at_entry  attention_span_score  social_skills_score  \
# 0             3.3                   2.0                  4.0
# 1             7.8                   4.0                  4.0
# 2             4.8                   1.0                  2.0
# 3             3.2                   4.0                  2.0
# 4             7.0                   4.0                  3.0
# ..            ...                   ...                  ...
# 495           4.5                   3.0                  5.0
# 496           4.5                   3.0                  5.0
# 497           4.2                   5.0                  3.0
# 498           3.9                   3.0                  1.0
# 499           5.6                   1.0                  4.0
#
#      cognitive_test_score  has_learning_difficulty  \
# 0                    85.0                      0.0
# 1                   110.0                      0.0
# 2                   123.0                      0.0
# ...

# %%
imp_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
dataset[qual] = imp_cat.fit_transform(dataset[qual])
dataset[qual]
# Out:
#     student_id entry_grade  gender parent_education family_income_bracket  \
# 0        S1000         3rd    Male         Master's                Middle
# 1        S1001         UKG  Female       Bachelor's                Middle
# 2        S1002         UKG    Male         Master's                Middle
# 3        S1003         2nd  Female         Master's                Middle
# 4        S1004         UKG  Female      High School                Middle
# ..         ...         ...     ...              ...                   ...
# 495      S1495         9th    Male      High School                  High
# 496      S1496         UKG    Male         Master's                Middle
# 497      S1497         6th  Female       Bachelor's                   Low
# 498      S1498         9th  Female              PhD                Middle
# 499      S1499         6th    Male      High School                Middle
#
#     language_proficiency
# 0                 Medium
# 1                    Low
# ...

# %%
label_encoders = {}
for col in qual:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
    label_encoders[col] = le

# %%
scaler = StandardScaler()
dataset[quan] = scaler.fit_transform(dataset[quan])
dataset[quan]
# Out:
#      age_at_entry  attention_span_score  social_skills_score  \
# 0       -0.847671             -0.695885             0.551773
# 1        1.510172              0.741894             0.551773
# 2       -0.061723             -1.414775            -0.845121
# 3       -0.900067              0.741894            -0.845121
# 4        1.091000              0.741894            -0.146674
# ..            ...                   ...                  ...
# 495     -0.218913              0.023004             1.250221
# 496     -0.218913              0.023004             1.250221
# 497     -0.376102              1.460784            -0.146674
# 498     -0.533292              0.023004            -1.543569
# 499      0.357449             -1.414775             0.551773
#
#      cognitive_test_score  has_learning_difficulty  \
# 0               -0.805449                -0.314485
# 1                0.641119                -0.314485
# 2                1.393334                -0.314485
# ...

# %%
preprocessed = pd.concat([dataset[quan], dataset[qual]], axis=1)

# %%
preprocessed.head()
# Out:
#    age_at_entry  attention_span_score  social_skills_score  \
# 0     -0.847671             -0.695885             0.551773
# 1      1.510172              0.741894             0.551773
# 2     -0.061723             -1.414775            -0.845121
# 3     -0.900067              0.741894            -0.845121
# 4      1.091000              0.741894            -0.146674
#
#    cognitive_test_score  has_learning_difficulty  parental_involvement_score  \
# 0             -0.805449                -0.314485                   -1.456708
# 1              0.641119                -0.314485                   -0.047899
# 2              1.393334                -0.314485                   -0.047899
# 3              0.004629                -0.314485                    1.360909
# 4             -1.499801                -0.314485                   -1.456708
#
#    high_IGCSE_performance  student_id  entry_grade  gender  parent_education  \
# ...

# %%
print(preprocessed.isnull().sum())
# Out:
# age_at_entry                  0
# attention_span_score          0
# social_skills_score           0
# cognitive_test_score          0
# has_learning_difficulty       0
# parental_involvement_score    0
# high_IGCSE_performance        0
# student_id                    0
# entry_grade                   0
# gender                        0
# parent_education              0
# family_income_bracket         0
# language_proficiency          0
# dtype: int64
